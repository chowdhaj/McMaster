# %% [markdown]
# ## Binary Operators on int and float

# %% [markdown]
# ![Screen%20Shot%202018-04-19%20at%204.59.23%20PM.png](attachment:Screen%20Shot%202018-04-19%20at%204.59.23%20PM.png)

# %% [markdown]
# ## Strings Syntax

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![Screen%20Shot%202018-04-19%20at%207.07.29%20PM.png](attachment:Screen%20Shot%202018-04-19%20at%207.07.29%20PM.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Tuples Syntax

# %% [markdown]
# ![Screen%20Shot%202018-04-19%20at%205.07.56%20PM.png](attachment:Screen%20Shot%202018-04-19%20at%205.07.56%20PM.png)

# %% [markdown]
# ## Lists Syntax

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Dictionaries Syntax

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Sets Syntax

# %% [markdown]
# ![Screen%20Shot%202018-04-19%20at%204.08.55%20PM.png](attachment:Screen%20Shot%202018-04-19%20at%204.08.55%20PM.png)
